# %%
text="""
Climate change includes both human-induced global warming and its large-scale impacts on weather patterns. There have been previous periods of climate change, but the current changes are more rapid than any known events in Earth's history.[2] The main cause is the emission of greenhouse gases, mostly carbon dioxide (CO
2) and methane. Burning fossil fuels for energy use creates most of these emissions. Agriculture, steel making, cement production, and forest loss are also significant sources.[3] Temperature rise is affected by climate feedbacks as well, such as the loss of sunlight-reflecting snow cover, and the release of carbon dioxide from drought-stricken forests. Collectively, these amplify global warming.[4]


CO
2 concentrations over the last 800,000 years as measured from ice cores (blue/green) and directly (black)
On land, temperatures have risen about twice as fast as the global average. Deserts are expanding, while heat waves and wildfires are becoming more common.[5] Increased warming in the Arctic has contributed to melting permafrost, glacial retreat and sea ice loss.[6] Higher temperatures are also causing more intense storms and other weather extremes.[7] In places such as coral reefs, mountains, and the Arctic, many species are forced to relocate, or become extinct, as their environment changes.[8] Climate change threatens people with food and water scarcity, increased flooding, extreme heat, more disease, and economic loss. It can also drive human migration.[9] The World Health Organization is calling climate change the greatest threat to global health in the 21st century.[10] Even if efforts to minimise future warming are successful, some effects will continue for centuries. These include sea level rise, as well as warmer and more acidic oceans.[11]

Many of these impacts are already felt at the current level of warming, which is about 1.2 °C (2.2 °F).[a][12] The Intergovernmental Panel on Climate Change (IPCC) has projected significant increases in these impacts as warming continues to 1.5 °C (2.7 °F) and beyond.[13] Additional warming increases the risk of triggering critical thresholds called tipping points.[14] Responding to these impacts involves both mitigation and adaptation.[15] Mitigation – limiting climate change – consists of reducing greenhouse gas emissions and removing them from the atmosphere.[15] Methods to achieve this include the development and deployment of low-carbon energy sources such as wind and solar, a phase-out of coal, enhanced energy efficiency, and forest preservation. Adaptation consists of adjusting to actual or expected climate,[15] such as through improved coastline protection, better disaster management, and the development of more resistant crops. Adaptation alone cannot avert the risk of "severe, widespread and irreversible" impacts.[16]

Under the 2015 Paris Agreement, nations collectively agreed to keep warming "well under 2.0 °C" (3.6 °F) through mitigation efforts. However, with pledges made under the Agreement, global warming would still reach about 2.8 °C by the end of the century.[17] Limiting warming to 1.5 °C would require halving emissions by 2030 and achieving net-zero emissions by 2050.[18]
"""

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
s1=list(STOP_WORDS)

# %%
s1
# Out:
# ['again',
#  'were',
#  'off',
#  '’re',
#  'he',
#  'himself',
#  'against',
#  'various',
#  'how',
#  'last',
#  'throughout',
#  'among',
#  'few',
#  'by',
#  'the',
#  'everywhere',
#  'such',
#  'almost',
#  'several',
#  'both',
#  'now',
#  'no',
#  'much',
#  'whether',
#  'me',
#  'i',
#  'twenty',
#  'so',
#  'namely',
#  'become',
#  'three',
#  'whence',
#  'thereafter',
#  '’ve',
#  'done',
#  'only',
#  'if',
#  '‘s',
#  'than',
#  'besides',
#  'front',
#  'nor',
#  'and',
#  'as',
#  'might',
#  'they',
#  "'d",
#  'do',
#  'hereby',
#  'whereafter',
#  'often',
#  'all',
#  'beside',
#  'had',
#  'of',
#  'hereupon',
#  '‘ve',
#  'along',
#  'noone',
#  'whither',
#  'who',
#  'whose',
#  'there',
#  'its',
#  'with',
#  "'re",
#  'therein',
#  'fifteen',
#  'please',
#  'afterwards',
#  'was',
#  'became',
#  'your',
#  'however',
#  'any',
#  "'m",
#  'everyone',
#  'five',
#  'hence',
#  'anyone',
#  'n‘t',
#  'across',
#  'already',
#  '‘d',
#  'least',
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2021-10-24 12:12:39.085427: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-10-24 12:12:39.085461: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
nlp=spacy.load("en_core_web_sm")

# %%
doc=nlp(text)

# %%
tokens=[token.text for token in doc]

# %%
tokens
# Out:
# ['\n',
#  'Climate',
#  'change',
#  'includes',
#  'both',
#  'human',
#  '-',
#  'induced',
#  'global',
#  'warming',
#  'and',
#  'its',
#  'large',
#  '-',
#  'scale',
#  'impacts',
#  'on',
#  'weather',
#  'patterns',
#  '.',
#  'There',
#  'have',
#  'been',
#  'previous',
#  'periods',
#  'of',
#  'climate',
#  'change',
#  ',',
#  'but',
#  'the',
#  'current',
#  'changes',
#  'are',
#  'more',
#  'rapid',
#  'than',
#  'any',
#  'known',
#  'events',
#  'in',
#  'Earth',
#  "'s",
#  'history.[2',
#  ']',
#  'The',
#  'main',
#  'cause',
#  'is',
#  'the',
#  'emission',
#  'of',
#  'greenhouse',
#  'gases',
#  ',',
#  'mostly',
#  'carbon',
#  'dioxide',
#  '(',
#  'CO',
#  '\n',
#  '2',
#  ')',
#  'and',
#  'methane',
#  '.',
#  'Burning',
#  'fossil',
#  'fuels',
#  'for',
#  'energy',
#  'use',
#  'creates',
#  'most',
#  'of',
#  'these',
#  'emissions',
#  '.',
#  'Agriculture',
#  ',',
#  'steel',
#  'making',
#  ',',
#  'cement',
#  'production',
#  ',',
#  'and',
# ...

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n\n'

# %%
word_frequencies={}
for word in doc:
    if word.text.lower() not in s1:
        if word.text not in  punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text]=1
            else:
                word_frequencies[word.text]+=1

# %%
word_frequencies
# Out:
# {'Climate': 3,
#  'change': 5,
#  'includes': 1,
#  'human': 2,
#  'induced': 1,
#  'global': 5,
#  'warming': 9,
#  'large': 1,
#  'scale': 1,
#  'impacts': 4,
#  'weather': 2,
#  'patterns': 1,
#  'previous': 1,
#  'periods': 1,
#  'climate': 4,
#  'current': 2,
#  'changes': 1,
#  'rapid': 1,
#  'known': 1,
#  'events': 1,
#  'Earth': 1,
#  'history.[2': 1,
#  'main': 1,
#  'cause': 1,
#  'emission': 1,
#  'greenhouse': 2,
#  'gases': 1,
#  'carbon': 3,
#  'dioxide': 2,
#  'CO': 2,
#  '2': 2,
#  'methane': 1,
#  'Burning': 1,
#  'fossil': 1,
#  'fuels': 1,
#  'energy': 3,
#  'use': 1,
#  'creates': 1,
#  'emissions': 4,
#  'Agriculture': 1,
#  'steel': 1,
#  'making': 1,
#  'cement': 1,
#  'production': 1,
#  'forest': 2,
#  'loss': 3,
#  'significant': 2,
#  'sources.[3': 1,
#  'Temperature': 1,
#  'rise': 2,
#  'affected': 1,
#  'feedbacks': 1,
#  'sunlight': 1,
#  'reflecting': 1,
#  'snow': 1,
#  'cover': 1,
#  'release': 1,
#  'drought': 1,
#  'stricken': 1,
#  'forests': 1,
# ...

# %%
m1=max(word_frequencies.values())

# %%
m1
# Out:
# 9

# %%
for word in word_frequencies.keys():
    word_frequencies[word]=word_frequencies[word]/m1

# %%
word_frequencies
# Out:
# {'Climate': 0.3333333333333333,
#  'change': 0.5555555555555556,
#  'includes': 0.1111111111111111,
#  'human': 0.2222222222222222,
#  'induced': 0.1111111111111111,
#  'global': 0.5555555555555556,
#  'warming': 1.0,
#  'large': 0.1111111111111111,
#  'scale': 0.1111111111111111,
#  'impacts': 0.4444444444444444,
#  'weather': 0.2222222222222222,
#  'patterns': 0.1111111111111111,
#  'previous': 0.1111111111111111,
#  'periods': 0.1111111111111111,
#  'climate': 0.4444444444444444,
#  'current': 0.2222222222222222,
#  'changes': 0.1111111111111111,
#  'rapid': 0.1111111111111111,
#  'known': 0.1111111111111111,
#  'events': 0.1111111111111111,
#  'Earth': 0.1111111111111111,
#  'history.[2': 0.1111111111111111,
#  'main': 0.1111111111111111,
#  'cause': 0.1111111111111111,
#  'emission': 0.1111111111111111,
#  'greenhouse': 0.2222222222222222,
#  'gases': 0.1111111111111111,
#  'carbon': 0.3333333333333333,
#  'dioxide': 0.2222222222222222,
#  'CO': 0.2222222222222222,
# ...

# %%
sentence_tokens=[sent for sent in doc.sents]

# %%
print(sentence_tokens)
# Out:
# [
# Climate change includes both human-induced global warming and its large-scale impacts on weather patterns., There have been previous periods of climate change, but the current changes are more rapid than any known events in Earth's history.[2], The main cause is the emission of greenhouse gases, mostly carbon dioxide (CO
# 2) and methane., Burning fossil fuels for energy use creates most of these emissions., Agriculture, steel making, cement production, and forest loss are also significant sources.[3, ], Temperature rise is affected by climate feedbacks as well, such as the loss of sunlight-reflecting snow cover, and the release of carbon dioxide from drought-stricken forests., Collectively, these amplify global warming.[4]
#
#
# CO
# 2 concentrations over the last 800,000 years as measured from ice cores (blue/green) and directly (black)
# ...

# %%
sentence_scores={}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent]=word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent]+=word_frequencies[word.text.lower()]

# %%
sentence_scores
# Out:
# {
#  Climate change includes both human-induced global warming and its large-scale impacts on weather patterns.: 4.0,
#  There have been previous periods of climate change, but the current changes are more rapid than any known events in Earth's history.[2]: 2.0000000000000004,
#  The main cause is the emission of greenhouse gases, mostly carbon dioxide (CO
#  2) and methane.: 1.5555555555555558,
#  Burning fossil fuels for energy use creates most of these emissions.: 1.2222222222222223,
#  Agriculture, steel making, cement production, and forest loss are also significant sources.[3: 1.3333333333333335,
#  Temperature rise is affected by climate feedbacks as well, such as the loss of sunlight-reflecting snow cover, and the release of carbon dioxide from drought-stricken forests.: 2.666666666666667,
#  Collectively, these amplify global warming.[4]
#
#
#  CO
#  2 concentrations over the last 800,000 years as measured from ice cores (blue/green) and directly (black): 2.444444444444445,
# ...

# %%
from heapq import nlargest

# %%
select_length=int(len(sentence_tokens)*0.3)

# %%
select_length
# Out:
# 7

# %%
summary=nlargest(select_length,sentence_scores,key=sentence_scores.get)

# %%
summary
# Out:
# [Responding to these impacts involves both mitigation and adaptation.[15] Mitigation – limiting climate change – consists of reducing greenhouse gas emissions and removing them from the atmosphere.[15] Methods to achieve this include the development and deployment of low-carbon energy sources such as wind and solar, a phase-out of coal, enhanced energy efficiency, and forest preservation.,
#  The Intergovernmental Panel on Climate Change (IPCC) has projected significant increases in these impacts as warming continues to 1.5 °C (2.7 °F) and beyond.[13],
#  Adaptation alone cannot avert the risk of "severe, widespread and irreversible" impacts.[16]
#
#  Under the 2015 Paris Agreement, nations collectively agreed to keep warming "well under 2.0 °C" (3.6 °F) through mitigation efforts.,
#
#  Climate change includes both human-induced global warming and its large-scale impacts on weather patterns.,
# ...

# %%
final_summary=[word.text for word in summary]
summary=' '.join(final_summary)

# %%
summary
# Out:
# 'Responding to these impacts involves both mitigation and adaptation.[15] Mitigation – limiting climate change – consists of reducing greenhouse gas emissions and removing them from the atmosphere.[15] Methods to achieve this include the development and deployment of low-carbon energy sources such as wind and solar, a phase-out of coal, enhanced energy efficiency, and forest preservation. The Intergovernmental Panel on Climate Change (IPCC) has projected significant increases in these impacts as warming continues to 1.5 °C (2.7 °F) and beyond.[13] Adaptation alone cannot avert the risk of "severe, widespread and irreversible" impacts.[16]\n\nUnder the 2015 Paris Agreement, nations collectively agreed to keep warming "well under 2.0 °C" (3.6 °F) through mitigation efforts. \nClimate change includes both human-induced global warming and its large-scale impacts on weather patterns. Many of these impacts are already felt at the current level of warming, which is about 1.2 °C (2.2 °F).[a]
# ...
